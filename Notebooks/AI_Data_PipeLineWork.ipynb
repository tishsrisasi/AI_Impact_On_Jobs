# %% [markdown]
# # Pipeline Work Jupyter Notebook file
# - This file replaces the Feature Engineer file (still in the directory)
# - Please refer to this file for notes on the new Features. Thank you!

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OrdinalEncoder

# %%
df = pd.read_csv('../Resources/AI_Impact_On_Jobs_2030.csv')

# %%
df.head(5) #checking first 5 records to see if data loaded successfully.
# Out:
#              Job_Title  Average_Salary  Years_Experience Education_Level  \
# 0       Security Guard           45795                28        Master's
# 1   Research Scientist          133355                20             PhD
# 2  Construction Worker          146216                 2     High School
# 3    Software Engineer          136530                13             PhD
# 4    Financial Analyst           70397                22     High School
#
#    AI_Exposure_Index  Tech_Growth_Factor  Automation_Probability_2030  \
# 0               0.18                1.28                         0.85
# 1               0.62                1.11                         0.05
# 2               0.86                1.18                         0.81
# 3               0.39                0.68                         0.60
# 4               0.52                1.46                         0.64
#
#   Risk_Category  Skill_1  Skill_2  Skill_3  Skill_4  Skill_5  Skill_6  \
# 0          High     0.45     0.10     0.46     0.33     0.14     0.65
# 1           Low     0.02     0.52     0.40     0.05     0.97     0.23
# 2          High     0.01     0.94     0.56     0.39     0.02     0.23
# 3        Medium     0.43     0.21     0.57     0.03     0.84     0.45
# 4        Medium     0.75     0.54     0.59     0.97     0.61     0.28
#
#    Skill_7  Skill_8  Skill_9  Skill_10
# 0     0.06     0.72     0.94      0.00
# 1     0.09     0.62     0.38      0.98
# 2     0.24     0.68     0.61      0.83
# 3     0.40     0.93     0.73      0.33
# 4     0.30     0.17     0.02      0.42

# %%
bins = [-1, 2, 5, 10, 20, float('inf')]
labels = ['Entry/Junior', 'Early Career', 'Mid-Level', 'Senior', 'Expert/Late']

def add_experience_band(X: pd.DataFrame) -> pd.DataFrame:
    X = X.copy()
    X['Experience_Band'] = pd.cut(
        X['Years_Experience'],
        bins=bins,
        labels=labels,
        right=False
    )
    X['Experience_Band_Code'] = X['Experience_Band'].cat.codes
    return X

# %%
bins2 = [-float('inf'), 30500, 100000, float('inf')]
labels2 = ['Low', 'Middle', 'High']

def add_income_band(X: pd.DataFrame) -> pd.DataFrame:
    X = X.copy()
    X['Income_Band'] = pd.cut(
        X['Average_Salary'],
        bins=bins2,
        labels=labels2,
        right=False
    )
    X['Income_Band_Code'] = X['Income_Band'].cat.codes
    return X

# %%
job_sector_map = {
    "Security Guard":      "Security & Protective Services",
    "Research Scientist":  "Research & Development",
    "Construction Worker": "Construction",
    "Software Engineer":   "Digital & Technology",
    "Financial Analyst":   "Finance & Professional Services",
    "AI Engineer":         "Digital & Technology",
    "Mechanic":            "Transport & Automotive Services",
    "Teacher":             "Education",
    "HR Specialist":       "Business & Professional Services",
    "Customer Support":    "Customer Service",
    "UX Researcher":       "Digital & Creative Industries",
    "Lawyer":              "Legal Services",
    "Data Scientist":      "Digital & Technology",
    "Graphic Designer":    "Creative Industries",
    "Retail Worker":       "Retail & Consumer Services",
    "Doctor":              "Health & Social Care",
    "Truck Driver":        "Transport & Logistics",
    "Chef":                "Hospitality & Catering",
    "Nurse":               "Health & Social Care",
    "Marketing Manager":   "Marketing & Professional Services",
}

def add_job_sector(X: pd.DataFrame) -> pd.DataFrame:
    X = X.copy()
    X['Job_Sector'] = X['Job_Title'].map(job_sector_map)
    X['Job_Sector_Code'], sector_uniques = pd.factorize(X['Job_Sector'])
    return X

# %%
labour_group_map = {
    # ** Public_Sector **
    "Teacher":          "Public_Sector",
    "Doctor":           "Public_Sector",
    "Nurse":            "Public_Sector",

    # ** Private_Professional **
    "Financial Analyst":"Private_Professional",
    "HR Specialist":    "Private_Professional",
    "Lawyer":           "Private_Professional",
    "Marketing Manager":"Private_Professional",

    # ** Digital_Creative **
    "Research Scientist":"Digital_Creative",
    "Software Engineer": "Digital_Creative",
    "AI Engineer":       "Digital_Creative",
    "UX Researcher":     "Digital_Creative",
    "Data Scientist":    "Digital_Creative",
    "Graphic Designer":  "Digital_Creative",

    # ** Manual_Trade_Service **
    "Security Guard":    "Manual_Trade_Service",
    "Construction Worker":"Manual_Trade_Service",
    "Mechanic":          "Manual_Trade_Service",
    "Customer Support":  "Manual_Trade_Service",
    "Retail Worker":     "Manual_Trade_Service",
    "Truck Driver":      "Manual_Trade_Service",
    "Chef":              "Manual_Trade_Service",
}

def add_labour_group(X: pd.DataFrame) -> pd.DataFrame:
    X = X.copy()
    X['Labour_Group'] = X['Job_Title'].map(labour_group_map)
    X['Labour_Group_Code'], group_uniques = pd.factorize(X['Labour_Group'])
    return X

# %%
risk_order = [['Low', 'Medium', 'High']]

risk_encoder = OrdinalEncoder(
    categories=risk_order,
    handle_unknown='use_encoded_value',
    unknown_value=-1
)

def encode_risk(X: pd.DataFrame) -> pd.DataFrame:
    X = X.copy()
    X['Risk_Category_Code'] = risk_encoder.fit_transform(X[['Risk_Category']])
    X['Risk_Category_Code'] = codes.astype(int)
    return X

# %%
education_order = [["High School", "Bachelor's", "Master's", "PhD"]]

education_encoder = OrdinalEncoder(
    categories = education_order,
    handle_unknown='use_encoded_value',
    unknown_value=-1
)

def encode_education(X: pd.DataFrame) -> pd.DataFrame:
    X = X.copy()
    X['Education_Level_Code'] = education_encoder.fit_transform(X[['Education_Level']])
    X['Education_Level_Code'] = codes.astype(int)
    return X

# %%
def add_job_title_code(X: pd.DataFrame) -> pd.DataFrame:
    X = X.copy()
    X['Job_Title_Code'], sector_uniques = pd.factorize(X['Job_Title'])
    return X

# %%
pipe = Pipeline(steps=[
    ('experience_binner', FunctionTransformer(add_experience_band, validate=False)),
    ('income_binner', FunctionTransformer(add_income_band, validate=False)),
    ('job_sector_mapper', FunctionTransformer(add_job_sector, validate=False)),
    ('labour_group_mapper', FunctionTransformer(add_labour_group, validate=False)),
    ('risk_to_ordinal', FunctionTransformer(encode_risk, validate=False)),
    ('education_to_ordinal', FunctionTransformer(encode_education, validate=False)),
    ('job_title_code_mapper', FunctionTransformer(add_job_title_code, validate=False))
])

# %%
df_transformed = pipe.fit_transform(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df_transformed = pipe.fit_transform(df)
#
# File c:\Users\tishs\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\tishs\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\pipeline.py:719, in Pipeline.fit_transform(self, X, y, **params)
#     680 """Fit the model and transform with the final estimator.
#     681
#     682 Fit all the transformers one after the other and sequentially transform
#    (...)    716     Transformed samples.
#     717 """
#     718 routed_params = self._check_method_params(method="fit_transform", props=params)
# --> 719 Xt = self._fit(X, y, routed_params)
#     721 last_step = self._final_estimator
#     722 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#
# File c:\Users\tishs\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\pipeline.py:589, in Pipeline._fit(self, X, y, routed_params, raw_params)
#     582 # Fit or load from cache the current transformer
#     583 step_params = self._get_metadata_for_step(
#     584     step_idx=step_idx,
#     585     step_params=routed_params[name],
#     586     all_params=raw_params,
#     587 )
# --> 589 X, fitted_transformer = fit_transform_one_cached(
#     590     cloned_transformer,
#     591     X,
#     592     y,
#     593     weight=None,
#     594     message_clsname="Pipeline",
#     595     message=self._log_message(step_idx),
#     596     params=step_params,
#     597 )
#     598 # Replace the transformer of the step with the fitted
#     599 # transformer. This is necessary when loading the transformer
#     600 # from the cache.
#     601 self.steps[step_idx] = (name, fitted_transformer)
#
# File c:\Users\tishs\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\memory.py:326, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     325 def __call__(self, *args, **kwargs):
# --> 326     return self.func(*args, **kwargs)
#
# File c:\Users\tishs\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\pipeline.py:1540, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1538 with _print_elapsed_time(message_clsname, message):
#    1539     if hasattr(transformer, "fit_transform"):
# -> 1540         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1541     else:
#    1542         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1543             X, **params.get("transform", {})
#    1544         )
#
# File c:\Users\tishs\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\tishs\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:894, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     879         warnings.warn(
#     880             (
#     881                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)    889             UserWarning,
#     890         )
#     892 if y is None:
#     893     # fit method of arity 1 (unsupervised transformation)
# --> 894     return self.fit(X, **fit_params).transform(X)
#     895 else:
#     896     # fit method of arity 2 (supervised transformation)
#     897     return self.fit(X, y, **fit_params).transform(X)
#
# File c:\Users\tishs\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\tishs\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_function_transformer.py:263, in FunctionTransformer.transform(self, X)
#     249 """Transform X using the forward function.
#     250
#     251 Parameters
#    (...)    260     Transformed input.
#     261 """
#     262 X = self._check_input(X, reset=False)
# --> 263 out = self._transform(X, func=self.func, kw_args=self.kw_args)
#     264 output_config = _get_output_config("transform", self)["dense"]
#     266 if hasattr(out, "columns") and self.feature_names_out is not None:
#     267     # check the consistency between the column provided by `transform` and
#     268     # the column names provided by `get_feature_names_out`.
#
# File c:\Users\tishs\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_function_transformer.py:390, in FunctionTransformer._transform(self, X, func, kw_args)
#     387 if func is None:
#     388     func = _identity
# --> 390 return func(X, **(kw_args if kw_args else {}))
#
# Cell In[24], line 12, in encode_risk(X)
#      10 X = X.copy()
#      11 X['Risk_Category_Code'] = risk_encoder.fit_transform(X[['Risk_Category']])
# ---> 12 X['Risk_Category_Code'] = codes.astype(int)
#      13 return X
#
# NameError: name 'codes' is not defined

# %%
df_transformed.head()
# Out:
#              Job_Title  Average_Salary  Years_Experience Education_Level  \
# 0       Security Guard           45795                28        Master's
# 1   Research Scientist          133355                20             PhD
# 2  Construction Worker          146216                 2     High School
# 3    Software Engineer          136530                13             PhD
# 4    Financial Analyst           70397                22     High School
#
#    AI_Exposure_Index  Tech_Growth_Factor  Automation_Probability_2030  \
# 0               0.18                1.28                         0.85
# 1               0.62                1.11                         0.05
# 2               0.86                1.18                         0.81
# 3               0.39                0.68                         0.60
# 4               0.52                1.46                         0.64
#
#   Risk_Category  Skill_1  Skill_2  ...  Experience_Band_Code  Income_Band  \
# 0          High     0.45     0.10  ...                     4       Middle
# 1           Low     0.02     0.52  ...                     4         High
# 2          High     0.01     0.94  ...                     1         High
# 3        Medium     0.43     0.21  ...                     3         High
# 4        Medium     0.75     0.54  ...                     4       Middle
#
#    Income_Band_Code                       Job_Sector  Job_Sector_Code  \
# 0                 1   Security & Protective Services                0
# 1                 2           Research & Development                1
# 2                 2                     Construction                2
# 3                 2             Digital & Technology                3
# 4                 1  Finance & Professional Services                4
#
#            Labour_Group  Labour_Group_Code  Risk_Category_Code  \
# 0  Manual_Trade_Service                  0                 2.0
# 1      Digital_Creative                  1                 0.0
# 2  Manual_Trade_Service                  0                 2.0
# 3      Digital_Creative                  1                 1.0
# 4  Private_Professional                  2                 1.0
#
#   Education_Level_Code  Job_Title_Code
# 0                  2.0               0
# 1                  3.0               1
# 2                  0.0               2
# 3                  3.0               3
# 4                  0.0               4
#
# [5 rows x 29 columns]

# %%
df_transformed[['Experience_Band', 'Experience_Band_Code']].value_counts(sort=True)
# Out:
# Experience_Band  Experience_Band_Code
# Expert/Late      4                       1032
# Senior           3                        983
# Mid-Level        2                        486
# Early Career     1                        301
# Entry/Junior     0                        198
# Name: count, dtype: int64

# %%
df_transformed[['Job_Sector','Job_Sector_Code']].value_counts(sort=True)
# Out:
# Job_Sector                         Job_Sector_Code
# Digital & Technology               3                  482
# Health & Social Care               13                 274
# Digital & Creative Industries      9                  167
# Education                          6                  166
# Creative Industries                11                 160
# Business & Professional Services   7                  157
# Construction                       2                  156
# Retail & Consumer Services         12                 155
# Security & Protective Services     0                  154
# Transport & Logistics              14                 153
# Finance & Professional Services    4                  151
# Research & Development             1                  149
# Hospitality & Catering             15                 141
# Transport & Automotive Services    5                  136
# Marketing & Professional Services  16                 134
# Customer Service                   8                  133
# Legal Services                     10                 132
# Name: count, dtype: int64

# %%
df_transformed[['Labour_Group','Labour_Group_Code']].value_counts(sort=True)
# Out:
# Labour_Group          Labour_Group_Code
# Manual_Trade_Service  0                    1028
# Digital_Creative      1                     958
# Private_Professional  2                     574
# Public_Sector         3                     440
# Name: count, dtype: int64

# %%
df_transformed[['Risk_Category','Risk_Category_Code']].value_counts(sort=True)
# Out:
# Risk_Category  Risk_Category_Code
# Medium         1.0                   1521
# High           2.0                    740
# Low            0.0                    739
# Name: count, dtype: int64

# %%
df_transformed[['Education_Level','Education_Level_Code']].value_counts(sort=True)
# Out:
# Education_Level  Education_Level_Code
# High School      0.0                     784
# Bachelor's       1.0                     765
# Master's         2.0                     735
# PhD              3.0                     716
# Name: count, dtype: int64

# %%
df_transformed[['Job_Title','Job_Title_Code']].value_counts(sort=True)
# Out:
# Job_Title            Job_Title_Code
# Software Engineer    3                 175
# Data Scientist       12                167
# UX Researcher        10                167
# Teacher              7                 166
# Graphic Designer     13                160
# HR Specialist        8                 157
# Construction Worker  2                 156
# Retail Worker        14                155
# Security Guard       0                 154
# Truck Driver         16                153
# Financial Analyst    4                 151
# Research Scientist   1                 149
# Nurse                18                142
# Chef                 17                141
# AI Engineer          5                 140
# Mechanic             6                 136
# Marketing Manager    19                134
# Customer Support     9                 133
# Lawyer               11                132
# Doctor               15                132
# Name: count, dtype: int64

# %%
df_transformed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Job_Title                    3000 non-null   object
#  1   Average_Salary               3000 non-null   int64
#  2   Years_Experience             3000 non-null   int64
#  3   Education_Level              3000 non-null   object
#  4   AI_Exposure_Index            3000 non-null   float64
#  5   Tech_Growth_Factor           3000 non-null   float64
#  6   Automation_Probability_2030  3000 non-null   float64
#  7   Risk_Category                3000 non-null   object
#  8   Skill_1                      3000 non-null   float64
#  9   Skill_2                      3000 non-null   float64
#  10  Skill_3                      3000 non-null   float64
#  11  Skill_4                      3000 non-null   float64
#  12  Skill_5                      3000 non-null   float64
#  13  Skill_6                      3000 non-null   float64
#  14  Skill_7                      3000 non-null   float64
#  15  Skill_8                      3000 non-null   float64
#  16  Skill_9                      3000 non-null   float64
#  17  Skill_10                     3000 non-null   float64
#  18  Experience_Band              3000 non-null   category
#  19  Experience_Band_Code         3000 non-null   int8
#  20  Income_Band                  3000 non-null   category
#  21  Income_Band_Code             3000 non-null   int8
#  22  Job_Sector                   3000 non-null   object
#  23  Job_Sector_Code              3000 non-null   int64
#  24  Labour_Group                 3000 non-null   object
#  25  Labour_Group_Code            3000 non-null   int64
#  26  Risk_Category_Code           3000 non-null   float64
#  27  Education_Level_Code         3000 non-null   float64
#  28  Job_Title_Code               3000 non-null   int64
# dtypes: category(2), float64(15), int64(5), int8(2), object(5)
# memory usage: 598.1+ KB

# %%
df_transformed.shape
# Out:
# (3000, 29)

# %%
df_transformed.head(3)
# Out:
#              Job_Title  Average_Salary  Years_Experience Education_Level  \
# 0       Security Guard           45795                28        Master's
# 1   Research Scientist          133355                20             PhD
# 2  Construction Worker          146216                 2     High School
#
#    AI_Exposure_Index  Tech_Growth_Factor  Automation_Probability_2030  \
# 0               0.18                1.28                         0.85
# 1               0.62                1.11                         0.05
# 2               0.86                1.18                         0.81
#
#   Risk_Category  Skill_1  Skill_2  ...  Experience_Band_Code  Income_Band  \
# 0          High     0.45     0.10  ...                     4       Middle
# 1           Low     0.02     0.52  ...                     4         High
# 2          High     0.01     0.94  ...                     1         High
#
#    Income_Band_Code                      Job_Sector  Job_Sector_Code  \
# 0                 1  Security & Protective Services                0
# 1                 2          Research & Development                1
# 2                 2                    Construction                2
#
#            Labour_Group  Labour_Group_Code  Risk_Category_Code  \
# 0  Manual_Trade_Service                  0                 2.0
# 1      Digital_Creative                  1                 0.0
# 2  Manual_Trade_Service                  0                 2.0
#
#   Education_Level_Code  Job_Title_Code
# 0                  2.0               0
# 1                  3.0               1
# 2                  0.0               2
#
# [3 rows x 29 columns]

# %%
df_transformed.to_csv('../Resources/AI_Impact_On_Jobs_2030_piped.csv', index=False)
